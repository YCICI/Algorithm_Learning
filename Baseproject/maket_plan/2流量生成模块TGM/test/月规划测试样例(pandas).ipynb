# %%
import pandas as pd
import numpy as np
import math
import json

import sys
sys.path.append('..')
import src.month_week_plan.solve_by_udf  as udf_func

# %%
# 获取基础数据

base_data = pd.read_csv('../data/base_data.csv',nrows=10)
base_data.head(2)
# Out:
#    Unnamed: 0          dt user_log_acct  my_hash_code  month_hash  \
# 0           0  2022-06-01         -Nope            50           4
# 1           1  2022-06-01          -sam            68          57
#
#   user_life_cycle_type_1st  model_a_1st  model_b_1st goal_group_1st  \
# 0                      成熟期            5            5           都市中产
# 1                      成熟期            5            3           小镇家庭
#
#    annual_clv_1st  ... com_base_cnt  free_base_cnt no_ctrl_base_cnt  \
# 0               5  ...     2.535171       5.856637        11.683798
# 1               5  ...     2.546215       2.906346         7.363674
#
#    strong_ctrl_base_cnt  normal_ctrl_base_cnt  com_cnt_rate  free_cnt_rate  \
# 0              0.196020              4.002024      0.992779       1.159169
# 1              0.065493              3.937758      1.281925       1.314577
#
#   strong_cnt_rate  normal_cnt_rate  nocontrol_cnt_rate
# 0        2.326014         0.942478            1.626886
# 1        2.147202         1.169328            2.069599
#
# [2 rows x 87 columns]

# %%
## 保量逻辑校验
pra1 = list(base_data.columns.values).index('com_login_cnt_last_month')
pra2 = list(base_data.columns.values).index('free_login_cnt_last_month')
pra3 = list(base_data.columns.values).index('strong_ctrl_login_cnt_last_month')
pra4 = list(base_data.columns.values).index('strong_ctrl_login_cnt_last_month')
pra5 = list(base_data.columns.values).index('no_ctrl_login_cnt_last_month')

basic_result_list = []
for indexs in base_data.index:
    print(base_data.loc[indexs].values[pra1:pra5])
    basic_result = udf_func.BasicGuarantee(base_data.loc[indexs].values[pra1],
                            base_data.loc[indexs].values[pra2],
                            base_data.loc[indexs].values[pra3],
                            base_data.loc[indexs].values[pra4],
                            base_data.loc[indexs].values[pra5])
    print(basic_result)
    basic_result_list.append(basic_result)

base_data['basic_result'] = basic_result_list
# Out:
# [0 0 0 0]
# {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 0}
# {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 0}
# [0 9 0 4]
# {'com': 0, 'free': 9, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 20}
# {'com': 0, 'free': 9, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 20}
# [0 0 0 0]
# {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 0}
# {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 0}
# [0 2 0 0]
# {'com': 0, 'free': 2, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 0}
# {'com': 0, 'free': 2, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 0}
# [0 0 0 3]
# {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 3}
# {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 3}
# [0 0 0 0]
# {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 0}
# {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 0}
# [0 0 2 0]
# {'com': 0, 'free': 0, 'strong_ctrl': 2, 'normal_ctrl': 2, 'no_ctrl': 7}
# {'com': 0, 'free': 0, 'strong_ctrl': 2, 'normal_ctrl': 2, 'no_ctrl': 7}
# [0 0 0 13]
# {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 17}
# {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 17}
# [2 0 0 1]
# {'com': 2, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 0}
# {'com': 2, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 0}
# [0 0 0 5]
# {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 14}
# {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 14}

# %%
## 业务补量逻辑
par1 = list(base_data.columns.values).index('basic_result')
par2  = list(base_data.columns.values).index('priority_type')
year_clv_threshold = 2
par4  = list(base_data.columns.values).index('gmv_year')
par5 = list(base_data.columns.values).index('clv_pred_1m')
month_clv_threshold = 50
par7  = list(base_data.columns.values).index('com_login_cnt_last_month')
par8 = list(base_data.columns.values).index('free_login_cnt_last_month')
par9 = list(base_data.columns.values).index('strong_ctrl_login_cnt_last_month')
par10  = list(base_data.columns.values).index('normal_ctrl_login_cnt_last_month')
par11 = list(base_data.columns.values).index('no_ctrl_login_cnt_last_month')
par12 = list(base_data.columns.values).index('my_hash_code')
par13 = list(base_data.columns.values).index('month_hash')

businessrule_plan_list  = []
businessrule_no_allocation_channel_list = []
channel_businessrule_max_list =[]
channel_businessrule_max_add_list = []

for indexs in base_data.index:
    # print(base_data.loc[indexs].values[par1:par13])
    businessrule_plan, businessrule_no_allocation_channel, channel_businessrule_max, channel_businessrule_max_add = udf_func.BusinessRuleSupplement(base_data.loc[indexs].values[par1],
                                                                                                                                                    base_data.loc[indexs].values[par2],
                                                                                                                                                    year_clv_threshold,
                                                                                                                                                    base_data.loc[indexs].values[par4],
                                                                                                                                                    base_data.loc[indexs].values[par5],
                                                                                                                                                    month_clv_threshold,
                                                                                                                                                    base_data.loc[indexs].values[par7],
                                                                                                                                                    base_data.loc[indexs].values[par8],
                                                                                                                                                    base_data.loc[indexs].values[par9],
                                                                                                                                                    base_data.loc[indexs].values[par10],
                                                                                                                                                    base_data.loc[indexs].values[par11],
                                                                                                                                                    base_data.loc[indexs].values[par12],
                                                                                                                                                    base_data.loc[indexs].values[par13])
    businessrule_plan_list.append(businessrule_plan)
    businessrule_no_allocation_channel_list.append(businessrule_no_allocation_channel)
    channel_businessrule_max_list.append(channel_businessrule_max)
    channel_businessrule_max_add_list.append(channel_businessrule_max_add)

base_data['businessrule_plan'] = businessrule_plan_list
base_data['businessrule_no_allocation_channel'] = businessrule_no_allocation_channel_list
base_data['channel_businessrule_max'] = channel_businessrule_max_list
base_data['channel_businessrule_max_add'] = channel_businessrule_max_add_list
# Out:
# basic_result {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 0}
# businessrule_plan        {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 0}
# businessrule_plan['com'] 0
# user_label == 'A1'
# channel_days 0.0
# my_hash_code > hash_precent
# businessrule_plan:                   {'com': 0, 'free': 1, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 0}
# businessrule_no_allocation_channel:  ['normal_ctrl']
# channel_businessrule_max:            {'com': 0.0}
# channel_businessrule_max_add:        {'com': 0, 'free': 1, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 0}
# basic_result {'com': 0, 'free': 9, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 20}
# businessrule_plan        {'com': 0, 'free': 9, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 20}
# businessrule_plan['com'] 0
# user_label == 'A2'
# clv > month_clv_threshold clv>50, 保量+阶跃
# businessrule_plan['normal_ctrl'] == 0 businessrule_plan['normal_ctrl'] +=1
# businessrule_plan:                   {'com': 0, 'free': 9, 'strong_ctrl': 0, 'normal_ctrl': 1, 'no_ctrl': 20}
# businessrule_no_allocation_channel:  []
# channel_businessrule_max:            {}
# channel_businessrule_max_add:        {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 1, 'no_ctrl': 0}
# basic_result {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 0}
# businessrule_plan        {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 0}
# businessrule_plan['com'] 0
# user_label == 'A2'
# clv > month_clv_threshold clv>50, 保量+阶跃
# businessrule_plan['normal_ctrl'] == 0 businessrule_plan['normal_ctrl'] +=1
# businessrule_plan:                   {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 1, 'no_ctrl': 0}
# businessrule_no_allocation_channel:  []
# channel_businessrule_max:            {}
# channel_businessrule_max_add:        {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 1, 'no_ctrl': 0}
# basic_result {'com': 0, 'free': 2, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 0}
# businessrule_plan        {'com': 0, 'free': 2, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 0}
# businessrule_plan['com'] 0
# user_label == 'A2'
# clv > month_clv_threshold clv>50, 保量+阶跃
# businessrule_plan['normal_ctrl'] == 0 businessrule_plan['normal_ctrl'] +=1
# businessrule_plan:                   {'com': 0, 'free': 2, 'strong_ctrl': 0, 'normal_ctrl': 1, 'no_ctrl': 0}
# businessrule_no_allocation_channel:  []
# channel_businessrule_max:            {}
# channel_businessrule_max_add:        {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 1, 'no_ctrl': 0}
# basic_result {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 3}
# businessrule_plan        {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 3}
# businessrule_plan['com'] 0
# user_label == 'A2'
# clv > month_clv_threshold clv>50, 保量+阶跃
# businessrule_plan['normal_ctrl'] == 0 businessrule_plan['normal_ctrl'] +=1
# businessrule_plan:                   {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 1, 'no_ctrl': 3}
# businessrule_no_allocation_channel:  []
# channel_businessrule_max:            {}
# channel_businessrule_max_add:        {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 1, 'no_ctrl': 0}
# basic_result {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 0}
# businessrule_plan        {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 0}
# businessrule_plan['com'] 0
# user_label == 'A2'
# clv > month_clv_threshold clv>50, 保量+阶跃
# businessrule_plan['normal_ctrl'] == 0 businessrule_plan['normal_ctrl'] +=1
# businessrule_plan:                   {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 1, 'no_ctrl': 0}
# businessrule_no_allocation_channel:  []
# channel_businessrule_max:            {}
# channel_businessrule_max_add:        {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 1, 'no_ctrl': 0}
# basic_result {'com': 0, 'free': 0, 'strong_ctrl': 2, 'normal_ctrl': 2, 'no_ctrl': 7}
# businessrule_plan        {'com': 0, 'free': 0, 'strong_ctrl': 2, 'normal_ctrl': 2, 'no_ctrl': 7}
# businessrule_plan['com'] 0
# user_label == 'A2'
# clv > month_clv_threshold clv>50, 保量+阶跃
# businessrule_plan:                   {'com': 0, 'free': 0, 'strong_ctrl': 2, 'normal_ctrl': 2, 'no_ctrl': 7}
# businessrule_no_allocation_channel:  []
# channel_businessrule_max:            {}
# channel_businessrule_max_add:        {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 0}
# basic_result {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 17}
# businessrule_plan        {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 17}
# businessrule_plan['com'] 0
# user_label == 'A1'
# channel_days 0.0
# my_hash_code > hash_precent
# businessrule_plan:                   {'com': 0, 'free': 1, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 17}
# businessrule_no_allocation_channel:  ['normal_ctrl']
# channel_businessrule_max:            {'com': 0.0}
# channel_businessrule_max_add:        {'com': 0, 'free': 1, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 0}
# basic_result {'com': 2, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 0}
# businessrule_plan        {'com': 2, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 0}
# businessrule_plan['com'] 2
# user_label == 'A2'
# clv <= month_clv_threshold clv < 50 保量
# businessrule_plan:                   {'com': 2, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 0}
# businessrule_no_allocation_channel:  []
# channel_businessrule_max:            {}
# channel_businessrule_max_add:        {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 0}
# basic_result {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 14}
# businessrule_plan        {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 14}
# businessrule_plan['com'] 0
# user_label == 'A1'
# channel_days 0.0
# my_hash_code <= hash_precent strong_ctrl+1
# businessrule_plan:                   {'com': 0, 'free': 1, 'strong_ctrl': 1, 'normal_ctrl': 0, 'no_ctrl': 14}
# businessrule_no_allocation_channel:  ['normal_ctrl']
# channel_businessrule_max:            {'com': 0.0}
# channel_businessrule_max_add:        {'com': 0, 'free': 1, 'strong_ctrl': 1, 'normal_ctrl': 0, 'no_ctrl': 0}

# %%
## 渠道上下限测试
columns_list = list(base_data.columns.values)
i_part_dt = columns_list.index('dt')
i_priority_type  = columns_list.index('priority_type')
i_my_hash_code = columns_list.index('my_hash_code')
i_channel_businessrule_max_add = columns_list.index('channel_businessrule_max_add')
i_channel_businessrule_max = columns_list.index('channel_businessrule_max')
i_com_max_login_count = columns_list.index('com_max_login_count')
i_free_max_login_count = columns_list.index('free_max_login_count')
i_strong_ctrl_max_login_count = columns_list.index('strong_ctrl_max_login_count')
i_normal_ctrl_max_login_count  = columns_list.index('normal_ctrl_max_login_count')
i_no_ctrl_max_login_count  = columns_list.index('no_ctrl_max_login_count')
i_com_login_cnt_last_month = columns_list.index('com_login_cnt_last_month')
i_free_login_cnt_last_month  = columns_list.index('free_login_cnt_last_month')
i_strong_ctrl_login_cnt_last_month = columns_list.index('strong_ctrl_login_cnt_last_month')
i_normal_ctrl_login_cnt_last_month = columns_list.index('normal_ctrl_login_cnt_last_month')
i_no_ctrl_login_cnt_last_month  = columns_list.index('no_ctrl_login_cnt_last_month')
i_is_acce_by_com = columns_list.index('is_acce_by_com')
i_is_acce_by_free = columns_list.index('is_acce_by_free')
i_is_acce_by_strong_ctrl = columns_list.index('is_acce_by_strong_ctrl')
i_is_acce_by_normal_ctrl = columns_list.index('is_acce_by_normal_ctrl') 
i_is_acce_by_no_ctrl = columns_list.index('is_acce_by_no_ctrl')
month_clv_threshold = 50
channel_max_adjust = 1.0
channel_preference = [1.0]
i_com_login_cnt_mtd = columns_list.index('com_login_cnt_mtd')
i_free_login_cnt_mtd = columns_list.index('free_login_cnt_mtd')
i_strong_ctrl_login_cnt_mtd = columns_list.index('strong_ctrl_login_cnt_mtd')
i_normal_ctrl_login_cnt_mtd = columns_list.index('normal_ctrl_login_cnt_mtd')
i_no_ctrl_login_cnt_mtd = columns_list.index('no_ctrl_login_cnt_mtd')
between_channel_adjust = 0

channel_max_login_days_list = []
for indexs in base_data.index:
    # print(base_data.loc[indexs].values[par1:par13])
    print("-"*10)
    channel_max_login_days = udf_func.get_user_channel_max_func(base_data.loc[indexs].values[i_part_dt],
                                                                    base_data.loc[indexs].values[i_priority_type],
                                                                    base_data.loc[indexs].values[i_my_hash_code],
                                                                    base_data.loc[indexs].values[i_channel_businessrule_max_add],
                                                                    base_data.loc[indexs].values[i_channel_businessrule_max],
                                                                    base_data.loc[indexs].values[i_com_max_login_count],
                                                                    base_data.loc[indexs].values[i_free_max_login_count],
                                                                    base_data.loc[indexs].values[i_strong_ctrl_max_login_count],
                                                                    base_data.loc[indexs].values[i_normal_ctrl_max_login_count],
                                                                    base_data.loc[indexs].values[i_no_ctrl_max_login_count],
                                                                    base_data.loc[indexs].values[i_com_login_cnt_last_month],
                                                                    base_data.loc[indexs].values[i_free_login_cnt_last_month],
                                                                    base_data.loc[indexs].values[i_strong_ctrl_login_cnt_last_month],
                                                                    base_data.loc[indexs].values[i_normal_ctrl_login_cnt_last_month],
                                                                    base_data.loc[indexs].values[i_no_ctrl_login_cnt_last_month],
                                                                    base_data.loc[indexs].values[i_is_acce_by_com],
                                                                    base_data.loc[indexs].values[i_is_acce_by_free],
                                                                    base_data.loc[indexs].values[i_is_acce_by_strong_ctrl],
                                                                    base_data.loc[indexs].values[i_is_acce_by_normal_ctrl],
                                                                    base_data.loc[indexs].values[i_is_acce_by_no_ctrl],
                                                                    month_clv_threshold,
                                                                    channel_max_adjust,
                                                                    channel_preference,
                                                                    base_data.loc[indexs].values[i_com_login_cnt_mtd],
                                                                    base_data.loc[indexs].values[i_free_login_cnt_mtd],
                                                                    base_data.loc[indexs].values[i_strong_ctrl_login_cnt_mtd],
                                                                    base_data.loc[indexs].values[i_normal_ctrl_login_cnt_mtd],
                                                                    base_data.loc[indexs].values[i_no_ctrl_login_cnt_mtd],
                                                                    between_channel_adjust)
    channel_max_login_days_list.append(channel_max_login_days)
    # print("-"*10)
base_data['channel_max_login_days'] = channel_max_login_days_list
# Out:
# ----------
# channel_businessrule_max_add {'com': 0, 'free': 1, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 0}
# channel_businessrule_max     {'com': 0.0}
# 1 {'com': 1, 'free': 1, 'strong_ctrl': 1, 'normal_ctrl': 1, 'no_ctrl': 1}
# channel_days 0.0
# com 1.2*上月 < 上限
# channel_max_login_days['com'] 0.0
# channel_days 0.0
# channel_days 0.0
# channel_days 0.0
# 2 {'com': 0.0, 'free': 0.0, 'strong_ctrl': 0.0, 'normal_ctrl': 0.0, 'no_ctrl': 0}
# channel_max_login_days {'com': 0.0, 'free': 1.0, 'strong_ctrl': 0.0, 'normal_ctrl': 0.0, 'no_ctrl': 0}
# ----------
# channel_businessrule_max_add {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 1, 'no_ctrl': 0}
# channel_businessrule_max     {}
# 1 {'com': 1, 'free': 1, 'strong_ctrl': 1, 'normal_ctrl': 1, 'no_ctrl': 1}
# channel_days 0.0
# com 1.2*上月 < 上限
# channel_max_login_days['com'] 0.0
#  my_hash_code <= adjust_day_hash_add channel_days += 1
# channel_days 11.0
# channel_days 0.0
#  my_hash_code <= adjust_day_hash_add channel_days += 1
# channel_days 5.0
# 2 {'com': 0.0, 'free': 11.0, 'strong_ctrl': 0.0, 'normal_ctrl': 5.0, 'no_ctrl': 20}
# channel_max_login_days {'com': 0.0, 'free': 11.0, 'strong_ctrl': 0.0, 'normal_ctrl': 6.0, 'no_ctrl': 20}
# ----------
# channel_businessrule_max_add {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 1, 'no_ctrl': 0}
# channel_businessrule_max     {}
# 1 {'com': 1, 'free': 1, 'strong_ctrl': 1, 'normal_ctrl': 1, 'no_ctrl': 1}
# channel_days 0.0
# com 1.2*上月 < 上限
# channel_max_login_days['com'] 0.0
# channel_days 0.0
# channel_days 0.0
# channel_days 0.0
# 2 {'com': 0.0, 'free': 0.0, 'strong_ctrl': 0.0, 'normal_ctrl': 0.0, 'no_ctrl': 0}
# channel_max_login_days {'com': 0.0, 'free': 0.0, 'strong_ctrl': 0.0, 'normal_ctrl': 1.0, 'no_ctrl': 0}
# ----------
# channel_businessrule_max_add {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 1, 'no_ctrl': 0}
# channel_businessrule_max     {}
# 1 {'com': 1, 'free': 1, 'strong_ctrl': 1, 'normal_ctrl': 1, 'no_ctrl': 1}
# channel_days 0.0
# com 1.2*上月 < 上限
# channel_max_login_days['com'] 0.0
# channel_days 2.0
# channel_days 0.0
# channel_days 0.0
# 2 {'com': 0.0, 'free': 2.0, 'strong_ctrl': 0.0, 'normal_ctrl': 0.0, 'no_ctrl': 0}
# channel_max_login_days {'com': 0.0, 'free': 2.0, 'strong_ctrl': 0.0, 'normal_ctrl': 1.0, 'no_ctrl': 0}
# ----------
# channel_businessrule_max_add {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 1, 'no_ctrl': 0}
# channel_businessrule_max     {}
# 1 {'com': 1, 'free': 1, 'strong_ctrl': 1, 'normal_ctrl': 1, 'no_ctrl': 1}
# channel_days 0.0
# com 1.2*上月 < 上限
# channel_max_login_days['com'] 0.0
# channel_days 0.0
# channel_days 0.0
# channel_days 3.0
# 2 {'com': 0.0, 'free': 0.0, 'strong_ctrl': 0.0, 'normal_ctrl': 3.0, 'no_ctrl': 3}
# channel_max_login_days {'com': 0.0, 'free': 0.0, 'strong_ctrl': 0.0, 'normal_ctrl': 4.0, 'no_ctrl': 3}
# ----------
# channel_businessrule_max_add {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 1, 'no_ctrl': 0}
# channel_businessrule_max     {}
# 1 {'com': 1, 'free': 1, 'strong_ctrl': 1, 'normal_ctrl': 1, 'no_ctrl': 1}
# channel_days 0.0
# com 1.2*上月 < 上限
# channel_max_login_days['com'] 0.0
# channel_days 0.0
# channel_days 0.0
# channel_days 0.0
# 2 {'com': 0.0, 'free': 0.0, 'strong_ctrl': 0.0, 'normal_ctrl': 0.0, 'no_ctrl': 0}
# channel_max_login_days {'com': 0.0, 'free': 0.0, 'strong_ctrl': 0.0, 'normal_ctrl': 1.0, 'no_ctrl': 0}
# ----------
# channel_businessrule_max_add {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 0}
# channel_businessrule_max     {}
# 1 {'com': 1, 'free': 1, 'strong_ctrl': 1, 'normal_ctrl': 1, 'no_ctrl': 1}
# channel_days 0.0
# com 1.2*上月 < 上限
# channel_max_login_days['com'] 0.0
# channel_days 0.0
#  my_hash_code <= adjust_day_hash_add channel_days += 1
# channel_days 3.0
# channel_days 0.0
# 2 {'com': 0.0, 'free': 0.0, 'strong_ctrl': 3.0, 'normal_ctrl': 0.0, 'no_ctrl': 7}
# channel_max_login_days {'com': 0.0, 'free': 0.0, 'strong_ctrl': 3.0, 'normal_ctrl': 0.0, 'no_ctrl': 7}
# ----------
# channel_businessrule_max_add {'com': 0, 'free': 1, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 0}
# channel_businessrule_max     {'com': 0.0}
# 1 {'com': 1, 'free': 1, 'strong_ctrl': 1, 'normal_ctrl': 1, 'no_ctrl': 1}
# channel_days 0.0
# com 1.2*上月 < 上限
# channel_max_login_days['com'] 0.0
# channel_days 0.0
# channel_days 0.0
# 2 {'com': 0.0, 'free': 0.0, 'strong_ctrl': 0.0, 'normal_ctrl': 14, 'no_ctrl': 17}
# channel_max_login_days {'com': 0.0, 'free': 1.0, 'strong_ctrl': 0.0, 'normal_ctrl': 14, 'no_ctrl': 17}
# ----------
# channel_businessrule_max_add {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 0}
# channel_businessrule_max     {}
# 1 {'com': 1, 'free': 1, 'strong_ctrl': 1, 'normal_ctrl': 1, 'no_ctrl': 1}
# channel_days 2.0
# com 1.2*上月 < 上限
# channel_max_login_days['com'] 2.0
# channel_days 0.0
# channel_days 0.0
# channel_days 1.0
# 2 {'com': 2.0, 'free': 0.0, 'strong_ctrl': 0.0, 'normal_ctrl': 1.0, 'no_ctrl': 0}
# channel_max_login_days {'com': 2.0, 'free': 0.0, 'strong_ctrl': 0.0, 'normal_ctrl': 1.0, 'no_ctrl': 0}
# ----------
# channel_businessrule_max_add {'com': 0, 'free': 1, 'strong_ctrl': 1, 'normal_ctrl': 0, 'no_ctrl': 0}
# channel_businessrule_max     {'com': 0.0}
# 1 {'com': 1, 'free': 1, 'strong_ctrl': 1, 'normal_ctrl': 1, 'no_ctrl': 1}
# channel_days 0.0
# com 1.2*上月 < 上限
# channel_max_login_days['com'] 0.0
# channel_days 0.0
# channel_days 0.0
# channel_days 6.0
# 2 {'com': 0.0, 'free': 0.0, 'strong_ctrl': 0.0, 'normal_ctrl': 6.0, 'no_ctrl': 14}
# channel_max_login_days {'com': 0.0, 'free': 1.0, 'strong_ctrl': 1.0, 'normal_ctrl': 6.0, 'no_ctrl': 14}

# %%
## 目标值和渠道成本测试样例
i_part_dt = columns_list.index('dt')
i_lower_lift_login_cnt = columns_list.index('lower_lift_login_cnt')
i_natural_pred_login_cnt_rest  = columns_list.index('natural_pred_login_cnt_rest')
i_login_cnt_mtd = columns_list.index('login_cnt_mtd')
i_no_ctrl_login_cnt_last_month  = columns_list.index('no_ctrl_login_cnt_last_month')
i_no_ctrl_login_cnt_mtd = columns_list.index('no_ctrl_login_cnt_mtd')

target_login_days_list = []
for indexs in base_data.index:
    target_login_days = udf_func.get_target_allocation_login(base_data.loc[indexs].values[i_part_dt],
                                                         base_data.loc[indexs].values[i_lower_lift_login_cnt],
                                                         base_data.loc[indexs].values[i_natural_pred_login_cnt_rest],
                                                         base_data.loc[indexs].values[i_login_cnt_mtd],
                                                         base_data.loc[indexs].values[i_no_ctrl_login_cnt_last_month] - base_data.loc[indexs].values[i_no_ctrl_login_cnt_mtd])
    target_login_days_list.append(target_login_days)
base_data['target_login_days'] = target_login_days_list
# 目标值


# 渠道成本
channel_type = ['com','free', 'strong_ctrl', 'normal_ctrl', 'no_ctrl']
i_com_login_cost = columns_list.index('com_login_cost')
i_free_login_cost = columns_list.index('free_login_cost')
i_strong_ctrl_login_cost = columns_list.index('strong_ctrl_login_cost')
i_normal_login_cost = columns_list.index('normal_login_cost')
i_no_ctrl_login_cost = columns_list.index('no_ctrl_login_cost')
i_com_login_cnt_per_dau = columns_list.index('com_login_cnt_per_dau')
i_free_login_cnt_per_dau = columns_list.index('free_login_cnt_per_dau')
i_strong_ctrl_login_cnt_per_dau = columns_list.index('strong_ctrl_login_cnt_per_dau')
i_normal_ctrl_login_cnt_per_dau = columns_list.index('normal_ctrl_login_cnt_per_dau')
i_no_ctrl_login_cnt_per_dau = columns_list.index('no_ctrl_login_cnt_per_dau')
i_com_quality_coeff = columns_list.index('com_quality_coeff')
i_free_quality_coeff = columns_list.index('free_quality_coeff')
i_strong_ctrl_quality_coeff = columns_list.index('strong_ctrl_quality_coeff')
i_normal_ctrl_quality_coeff = columns_list.index('normal_ctrl_quality_coeff')
i_no_ctrl_quality_coeff = columns_list.index('no_ctrl_quality_coeff')

channel_login_costs_list = []
for indexs in base_data.index:
    channel_login_costs = udf_func.get_channel_login_costs(channel_type,
                                                        base_data.loc[indexs].values[i_com_login_cost],
                                                        base_data.loc[indexs].values[i_free_login_cost],
                                                        base_data.loc[indexs].values[i_strong_ctrl_login_cost],
                                                        base_data.loc[indexs].values[i_normal_login_cost],
                                                        base_data.loc[indexs].values[i_no_ctrl_login_cost],
                                                        base_data.loc[indexs].values[i_com_login_cnt_per_dau],
                                                        base_data.loc[indexs].values[i_free_login_cnt_per_dau],
                                                        base_data.loc[indexs].values[i_strong_ctrl_login_cnt_per_dau],
                                                        base_data.loc[indexs].values[i_normal_ctrl_login_cnt_per_dau],
                                                        base_data.loc[indexs].values[i_no_ctrl_login_cnt_per_dau],
                                                        base_data.loc[indexs].values[i_com_quality_coeff],
                                                        base_data.loc[indexs].values[i_free_quality_coeff],
                                                        base_data.loc[indexs].values[i_strong_ctrl_quality_coeff],
                                                        base_data.loc[indexs].values[i_normal_ctrl_quality_coeff],
                                                        base_data.loc[indexs].values[i_no_ctrl_quality_coeff])
    channel_login_costs_list.append(channel_login_costs)
        
base_data['channel_login_costs'] = channel_login_costs_list

# %%
# 测试贪心算法
columns_list = list(base_data.columns.values)
i_channel_login_costs = columns_list.index('channel_login_costs')
i_target_login_days = columns_list.index('target_login_days')
i_businessrule_no_allocation_channel = columns_list.index('businessrule_no_allocation_channel')
i_businessrule_plan = columns_list.index('businessrule_plan')
i_channel_max_login_days = columns_list.index('channel_max_login_days')

greedy_result_list = []
for indexs in base_data.index:
    print("-"*20)
    greedy_result = udf_func.GreedySolver(base_data.loc[indexs].values[i_target_login_days],
                                        base_data.loc[indexs].values[i_businessrule_no_allocation_channel],
                                        base_data.loc[indexs].values[i_businessrule_plan],
                                        base_data.loc[indexs].values[i_channel_max_login_days],
                                        base_data.loc[indexs].values[i_channel_login_costs])
    greedy_result_list.append(channel_login_costs)
        
base_data['greedy_result'] = greedy_result_list
# Out:
# --------------------
# target_login_days                 : 35
# businessrule_no_allocation_channel: ['normal_ctrl']
# businessrule_result               : {'com': 0, 'free': 1, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 0}
# channel_max_login_days            : {'com': 0.0, 'free': 1.0, 'strong_ctrl': 0.0, 'normal_ctrl': 0.0, 'no_ctrl': 0}
# channel_login_costs               : {'com': -18.114666354016535, 'free': 0.0, 'strong_ctrl': 0.12350513876550206, 'normal_ctrl': 5.740355949744533, 'no_ctrl': 4.971470124964464}
# target_login_days >0: greedy solver
# 待分配的渠道: com
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 35 = 35 - 0
# 渠道上限修正为 渠道上限 - 已分配次数
# 0 = 0 - 0
# used_day = min(channel_max_day, should_target_login_cnt)
# 0 = min(0 , 35)
# target_login_days: 35
# 待分配的渠道: free
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 34 = 35 - 1
# 渠道上限修正为 渠道上限 - 已分配次数
# 0 = 1 - 1
# used_day = min(channel_max_day, should_target_login_cnt)
# 0 = min(0 , 34)
# target_login_days: 35
# 待分配的渠道: strong_ctrl
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 35 = 35 - 0
# 渠道上限修正为 渠道上限 - 已分配次数
# 0 = 0 - 0
# used_day = min(channel_max_day, should_target_login_cnt)
# 0 = min(0 , 35)
# target_login_days: 35
# 待分配的渠道: no_ctrl
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 35 = 35 - 0
# 该渠道不可分配
# 待分配的渠道: normal_ctrl
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 35 = 35 - 0
# 该渠道不可分配
# greedy_plan: {'com': 0, 'free': 1, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 0}
# --------------------
# target_login_days                 : -20
# businessrule_no_allocation_channel: []
# businessrule_result               : {'com': 0, 'free': 9, 'strong_ctrl': 0, 'normal_ctrl': 1, 'no_ctrl': 20}
# channel_max_login_days            : {'com': 0.0, 'free': 11.0, 'strong_ctrl': 0.0, 'normal_ctrl': 6.0, 'no_ctrl': 20}
# channel_login_costs               : {'com': -16.00142710631649, 'free': 0.0, 'strong_ctrl': 0.10571275353385219, 'normal_ctrl': 5.022442079724738, 'no_ctrl': 3.6156624829402193}
# target_login_days <=0: greedy_plan = businessrule_result
# greedy_plan: {'com': 0, 'free': 9, 'strong_ctrl': 0, 'normal_ctrl': 1, 'no_ctrl': 20}
# --------------------
# target_login_days                 : 21
# businessrule_no_allocation_channel: []
# businessrule_result               : {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 1, 'no_ctrl': 0}
# channel_max_login_days            : {'com': 0.0, 'free': 0.0, 'strong_ctrl': 0.0, 'normal_ctrl': 1.0, 'no_ctrl': 0}
# channel_login_costs               : {'com': -14.985551284885458, 'free': 0.0, 'strong_ctrl': 2.860308645226587, 'normal_ctrl': 3.00131561044475, 'no_ctrl': 2.6448595667908346}
# target_login_days >0: greedy solver
# 待分配的渠道: com
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 21 = 21 - 0
# 渠道上限修正为 渠道上限 - 已分配次数
# 0 = 0 - 0
# used_day = min(channel_max_day, should_target_login_cnt)
# 0 = min(0 , 21)
# target_login_days: 21
# 待分配的渠道: free
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 21 = 21 - 0
# 渠道上限修正为 渠道上限 - 已分配次数
# 0 = 0 - 0
# used_day = min(channel_max_day, should_target_login_cnt)
# 0 = min(0 , 21)
# target_login_days: 21
# 待分配的渠道: no_ctrl
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 21 = 21 - 0
# 该渠道不可分配
# 待分配的渠道: strong_ctrl
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 21 = 21 - 0
# 渠道上限修正为 渠道上限 - 已分配次数
# 0 = 0 - 0
# used_day = min(channel_max_day, should_target_login_cnt)
# 0 = min(0 , 21)
# target_login_days: 21
# 待分配的渠道: normal_ctrl
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 20 = 21 - 1
# 渠道上限修正为 渠道上限 - 已分配次数
# 0 = 1 - 1
# used_day = min(channel_max_day, should_target_login_cnt)
# 0 = min(0 , 20)
# target_login_days: 21
# greedy_plan: {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 1, 'no_ctrl': 0}
# --------------------
# target_login_days                 : 11
# businessrule_no_allocation_channel: []
# businessrule_result               : {'com': 0, 'free': 2, 'strong_ctrl': 0, 'normal_ctrl': 1, 'no_ctrl': 0}
# channel_max_login_days            : {'com': 0.0, 'free': 2.0, 'strong_ctrl': 0.0, 'normal_ctrl': 1.0, 'no_ctrl': 0}
# channel_login_costs               : {'com': -11.635894047100292, 'free': 0.0, 'strong_ctrl': 0.7239613507421293, 'normal_ctrl': 3.5784807728524153, 'no_ctrl': 3.752005521991615}
# target_login_days >0: greedy solver
# 待分配的渠道: com
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 11 = 11 - 0
# 渠道上限修正为 渠道上限 - 已分配次数
# 0 = 0 - 0
# used_day = min(channel_max_day, should_target_login_cnt)
# 0 = min(0 , 11)
# target_login_days: 11
# 待分配的渠道: free
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 9 = 11 - 2
# 渠道上限修正为 渠道上限 - 已分配次数
# 0 = 2 - 2
# used_day = min(channel_max_day, should_target_login_cnt)
# 0 = min(0 , 9)
# target_login_days: 11
# 待分配的渠道: strong_ctrl
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 11 = 11 - 0
# 渠道上限修正为 渠道上限 - 已分配次数
# 0 = 0 - 0
# used_day = min(channel_max_day, should_target_login_cnt)
# 0 = min(0 , 11)
# target_login_days: 11
# 待分配的渠道: normal_ctrl
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 10 = 11 - 1
# 渠道上限修正为 渠道上限 - 已分配次数
# 0 = 1 - 1
# used_day = min(channel_max_day, should_target_login_cnt)
# 0 = min(0 , 10)
# target_login_days: 11
# 待分配的渠道: no_ctrl
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 11 = 11 - 0
# 该渠道不可分配
# greedy_plan: {'com': 0, 'free': 2, 'strong_ctrl': 0, 'normal_ctrl': 1, 'no_ctrl': 0}
# --------------------
# target_login_days                 : 28
# businessrule_no_allocation_channel: []
# businessrule_result               : {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 1, 'no_ctrl': 3}
# channel_max_login_days            : {'com': 0.0, 'free': 0.0, 'strong_ctrl': 0.0, 'normal_ctrl': 4.0, 'no_ctrl': 3}
# channel_login_costs               : {'com': -8.432188568907694, 'free': 0.0, 'strong_ctrl': 2.0808874620818294, 'normal_ctrl': 2.628421772181804, 'no_ctrl': 2.1181209278277913}
# target_login_days >0: greedy solver
# 待分配的渠道: com
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 28 = 28 - 0
# 渠道上限修正为 渠道上限 - 已分配次数
# 0 = 0 - 0
# used_day = min(channel_max_day, should_target_login_cnt)
# 0 = min(0 , 28)
# target_login_days: 28
# 待分配的渠道: free
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 28 = 28 - 0
# 渠道上限修正为 渠道上限 - 已分配次数
# 0 = 0 - 0
# used_day = min(channel_max_day, should_target_login_cnt)
# 0 = min(0 , 28)
# target_login_days: 28
# 待分配的渠道: strong_ctrl
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 28 = 28 - 0
# 渠道上限修正为 渠道上限 - 已分配次数
# 0 = 0 - 0
# used_day = min(channel_max_day, should_target_login_cnt)
# 0 = min(0 , 28)
# target_login_days: 28
# 待分配的渠道: no_ctrl
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 25 = 28 - 3
# 该渠道不可分配
# 待分配的渠道: normal_ctrl
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 27 = 28 - 1
# 渠道上限修正为 渠道上限 - 已分配次数
# 3 = 4 - 1
# used_day = min(channel_max_day, should_target_login_cnt)
# 3 = min(3 , 27)
# target_login_days: 25
# greedy_plan: {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 4, 'no_ctrl': 3}
# --------------------
# target_login_days                 : 19
# businessrule_no_allocation_channel: []
# businessrule_result               : {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 1, 'no_ctrl': 0}
# channel_max_login_days            : {'com': 0.0, 'free': 0.0, 'strong_ctrl': 0.0, 'normal_ctrl': 1.0, 'no_ctrl': 0}
# channel_login_costs               : {'com': -10.823663936253427, 'free': 0.0, 'strong_ctrl': 1.0739300845282065, 'normal_ctrl': 2.7789654754841036, 'no_ctrl': 2.1741977877641867}
# target_login_days >0: greedy solver
# 待分配的渠道: com
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 19 = 19 - 0
# 渠道上限修正为 渠道上限 - 已分配次数
# 0 = 0 - 0
# used_day = min(channel_max_day, should_target_login_cnt)
# 0 = min(0 , 19)
# target_login_days: 19
# 待分配的渠道: free
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 19 = 19 - 0
# 渠道上限修正为 渠道上限 - 已分配次数
# 0 = 0 - 0
# used_day = min(channel_max_day, should_target_login_cnt)
# 0 = min(0 , 19)
# target_login_days: 19
# 待分配的渠道: strong_ctrl
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 19 = 19 - 0
# 渠道上限修正为 渠道上限 - 已分配次数
# 0 = 0 - 0
# used_day = min(channel_max_day, should_target_login_cnt)
# 0 = min(0 , 19)
# target_login_days: 19
# 待分配的渠道: no_ctrl
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 19 = 19 - 0
# 该渠道不可分配
# 待分配的渠道: normal_ctrl
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 18 = 19 - 1
# 渠道上限修正为 渠道上限 - 已分配次数
# 0 = 1 - 1
# used_day = min(channel_max_day, should_target_login_cnt)
# 0 = min(0 , 18)
# target_login_days: 19
# greedy_plan: {'com': 0, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 1, 'no_ctrl': 0}
# --------------------
# target_login_days                 : 18
# businessrule_no_allocation_channel: []
# businessrule_result               : {'com': 0, 'free': 0, 'strong_ctrl': 2, 'normal_ctrl': 2, 'no_ctrl': 7}
# channel_max_login_days            : {'com': 0.0, 'free': 0.0, 'strong_ctrl': 3.0, 'normal_ctrl': 0.0, 'no_ctrl': 7}
# channel_login_costs               : {'com': -8.708373462901662, 'free': 0.0, 'strong_ctrl': 1.6530217194116246, 'normal_ctrl': 3.0202076654539782, 'no_ctrl': 2.401918937234265}
# target_login_days >0: greedy solver
# 待分配的渠道: com
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 18 = 18 - 0
# 渠道上限修正为 渠道上限 - 已分配次数
# 0 = 0 - 0
# used_day = min(channel_max_day, should_target_login_cnt)
# 0 = min(0 , 18)
# target_login_days: 18
# 待分配的渠道: free
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 18 = 18 - 0
# 渠道上限修正为 渠道上限 - 已分配次数
# 0 = 0 - 0
# used_day = min(channel_max_day, should_target_login_cnt)
# 0 = min(0 , 18)
# target_login_days: 18
# 待分配的渠道: strong_ctrl
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 16 = 18 - 2
# 渠道上限修正为 渠道上限 - 已分配次数
# 1 = 3 - 2
# used_day = min(channel_max_day, should_target_login_cnt)
# 1 = min(1 , 16)
# target_login_days: 17
# 待分配的渠道: no_ctrl
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 10 = 17 - 7
# 该渠道不可分配
# 待分配的渠道: normal_ctrl
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 15 = 17 - 2
# 渠道上限修正为 渠道上限 - 已分配次数
# -2 = 0 - 2
# used_day = min(channel_max_day, should_target_login_cnt)
# -2 = min(-2 , 15)
# target_login_days: 19
# greedy_plan: {'com': 0, 'free': 0, 'strong_ctrl': 3, 'normal_ctrl': 0, 'no_ctrl': 7}
# --------------------
# target_login_days                 : 14
# businessrule_no_allocation_channel: ['normal_ctrl']
# businessrule_result               : {'com': 0, 'free': 1, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 17}
# channel_max_login_days            : {'com': 0.0, 'free': 1.0, 'strong_ctrl': 0.0, 'normal_ctrl': 14, 'no_ctrl': 17}
# channel_login_costs               : {'com': -17.401960021423967, 'free': 0.0, 'strong_ctrl': 0.12364591931308001, 'normal_ctrl': 5.800847859459948, 'no_ctrl': 5.566980112141692}
# target_login_days >0: greedy solver
# 待分配的渠道: com
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 14 = 14 - 0
# 渠道上限修正为 渠道上限 - 已分配次数
# 0 = 0 - 0
# used_day = min(channel_max_day, should_target_login_cnt)
# 0 = min(0 , 14)
# target_login_days: 14
# 待分配的渠道: free
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 13 = 14 - 1
# 渠道上限修正为 渠道上限 - 已分配次数
# 0 = 1 - 1
# used_day = min(channel_max_day, should_target_login_cnt)
# 0 = min(0 , 13)
# target_login_days: 14
# 待分配的渠道: strong_ctrl
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 14 = 14 - 0
# 渠道上限修正为 渠道上限 - 已分配次数
# 0 = 0 - 0
# used_day = min(channel_max_day, should_target_login_cnt)
# 0 = min(0 , 14)
# target_login_days: 14
# 待分配的渠道: no_ctrl
# 待分配的次数 = target_login_days - businessrule_result[index]:
# -3 = 14 - 17
# 该渠道不可分配
# 待分配的渠道: normal_ctrl
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 14 = 14 - 0
# 该渠道不可分配
# greedy_plan: {'com': 0, 'free': 1, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 17}
# --------------------
# target_login_days                 : 19
# businessrule_no_allocation_channel: []
# businessrule_result               : {'com': 2, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 0, 'no_ctrl': 0}
# channel_max_login_days            : {'com': 2.0, 'free': 0.0, 'strong_ctrl': 0.0, 'normal_ctrl': 1.0, 'no_ctrl': 0}
# channel_login_costs               : {'com': -10.077430781073991, 'free': 0.0, 'strong_ctrl': 0.6065708826261691, 'normal_ctrl': 3.1123133935465748, 'no_ctrl': 2.3318123014963166}
# target_login_days >0: greedy solver
# 待分配的渠道: com
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 17 = 19 - 2
# 渠道上限修正为 渠道上限 - 已分配次数
# 0 = 2 - 2
# used_day = min(channel_max_day, should_target_login_cnt)
# 0 = min(0 , 17)
# target_login_days: 19
# 待分配的渠道: free
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 19 = 19 - 0
# 渠道上限修正为 渠道上限 - 已分配次数
# 0 = 0 - 0
# used_day = min(channel_max_day, should_target_login_cnt)
# 0 = min(0 , 19)
# target_login_days: 19
# 待分配的渠道: strong_ctrl
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 19 = 19 - 0
# 渠道上限修正为 渠道上限 - 已分配次数
# 0 = 0 - 0
# used_day = min(channel_max_day, should_target_login_cnt)
# 0 = min(0 , 19)
# target_login_days: 19
# 待分配的渠道: no_ctrl
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 19 = 19 - 0
# 该渠道不可分配
# 待分配的渠道: normal_ctrl
# 待分配的次数 = target_login_days - businessrule_result[index]:
# 19 = 19 - 0
# 渠道上限修正为 渠道上限 - 已分配次数
# 1 = 1 - 0
# used_day = min(channel_max_day, should_target_login_cnt)
# 1 = min(1 , 19)
# target_login_days: 18
# greedy_plan: {'com': 2, 'free': 0, 'strong_ctrl': 0, 'normal_ctrl': 1, 'no_ctrl': 0}
# --------------------
# target_login_days                 : -14
# businessrule_no_allocation_channel: ['normal_ctrl']
# businessrule_result               : {'com': 0, 'free': 1, 'strong_ctrl': 1, 'normal_ctrl': 0, 'no_ctrl': 14}
# channel_max_login_days            : {'com': 0.0, 'free': 1.0, 'strong_ctrl': 1.0, 'normal_ctrl': 6.0, 'no_ctrl': 14}
# channel_login_costs               : {'com': -17.401960021423967, 'free': 0.0, 'strong_ctrl': 0.12364591931308001, 'normal_ctrl': 5.800847859459948, 'no_ctrl': 5.566980112141692}
# target_login_days <=0: greedy_plan = businessrule_result
# greedy_plan: {'com': 0, 'free': 1, 'strong_ctrl': 1, 'normal_ctrl': 0, 'no_ctrl': 14}
